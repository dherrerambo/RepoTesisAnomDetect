# %% [markdown]
# # Heart Faliure

# %%
import time
start = time.time()
dataset_name="heart_faliure"
contamination = 0.01

# %%
from importlib.metadata import version
print(f'lib_anomaly=={version("lib_anomaly")}')

from lib_anomaly import getLogger
logger = getLogger(name=dataset_name)

import pathlib
from lib_anomaly.params import get_params
from lib_anomaly.experiment import make_experiment
# Out:
# lib_anomaly==0.1

# %%
params = get_params(
                path_current_file=pathlib.Path(pathlib.Path().absolute())
                , dataset_name=dataset_name
                , contamination=contamination
                , logger=logger
            )
dict((k,v) for k,v in params.items() if k not in ["PROJECT_NAME","S3BUCKET","ROOT_PATH"])
# Out:
# {'dataset_name': 'heart_faliure',
#  'contamination': 0.01,
#  'scoring_metric': 'roc_auc',
#  'anomaly_threshold': 0.3,
#  'random_state': None,
#  'make_plots': True,
#  'show_plots': True,
#  'show_title': True,
#  'n_experiments': 1,
#  'debug': False}

# %%
data, results, params = make_experiment(logger=logger, **params)

# resp
# Out:
# :::::::::::::::::::::::::::::::::::::::::::::::::: 1 heart_faliure 20230818210927231826 ::::::::::::::::::::::::::::::::::::::::::::::::::
# ...
# AB: 100%|██████████| 6/6 [00:10<00:00,  1.76s/it]
# :::::::::::::::::::::::::::::::::::::::::::::::::: lof ::::::::::::::::::::::::::::::::::::::::::::::::::
# :::::::::::::::::::::::::::::::::::::::::::::::::: iforest ::::::::::::::::::::::::::::::::::::::::::::::::::
# :::::::::::::::::::::::::::::::::::::::::::::::::: autoencoder ::::::::::::::::::::::::::::::::::::::::::::::::::
# :::::::::::::::::::::::::::::::::::::::::::::::::: ensamble ::::::::::::::::::::::::::::::::::::::::::::::::::
# :::::::::::::::::::::::::::::::::::::::::::::::::: ensamble_p_0_3 ::::::::::::::::::::::::::::::::::::::::::::::::::
# ::::::::::::::::::::::::::::::::::::::::::::::::::  RESULTS  ::::::::::::::::::::::::::::::::::::::::::::::::::

# %%
t = time.time()-start

if t>=(60*60):
    t = f"{round(t/(60*60),2)}hrs."
elif t>120 and t<(60*60):
    t = f"{round(t/(60),2)}min."
elif t<120:
    t = f"{round(t,0)}sec."

print(f"Run time = {t}")
# Out:
# Run time = 4.17min.
