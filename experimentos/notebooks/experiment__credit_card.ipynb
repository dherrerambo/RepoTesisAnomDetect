# %% [markdown]
# # Credit Card

# %%
import time
start = time.time()
dataset_name="credit_card"
contamination = 0.01
# Out:
# ... Loading: lib_anomaly.params

# %%
from importlib.metadata import version
print(f'lib_anomaly=={version("lib_anomaly")}')

from lib_anomaly import getLogger
logger = getLogger(name=dataset_name)

import pathlib
from lib_anomaly.params import get_params
from lib_anomaly.experiment import make_experiment

# %%
params = get_params(
                path_current_file=pathlib.Path(pathlib.Path().absolute())
                , dataset_name=dataset_name
                , contamination=contamination
                , logger=logger
            )
dict((k,v) for k,v in params.items() if k not in ["PROJECT_NAME","S3BUCKET","ROOT_PATH"])
# Out:
# {'dataset_name': 'credit_card',
#  'scoring_metric': 'roc_auc',
#  'anomaly_threshold': 0.3,
#  'random_state': None,
#  'contamination': 0.1,
#  'make_plots': True,
#  'show_plots': True,
#  'show_title': True,
#  'n_experiments': 1,
#  'debug': False}

# %%
resp = make_experiment(loegger=logger, **params)

# resp
# Out:
# AB: 100%|██████████| 6/6 [3:13:39<00:00, 1936.60s/it]
# AB: 100%|██████████| 6/6 [2:41:14<00:00, 1612.36s/it]
# AB: 100%|██████████| 6/6 [2:48:42<00:00, 1687.01s/it]
# 8867/8867 [==============================] - 9s 943us/step
# 8867/8867 [==============================] - 8s 946us/step
# 8867/8867 [==============================] - 8s 903us/step
# AB: 100%|██████████| 6/6 [2:39:20<00:00, 1593.34s/it]
# AB: 100%|██████████| 6/6 [3:07:41<00:00, 1876.84s/it]
# AB: 100%|██████████| 6/6 [3:03:41<00:00, 1836.89s/it]
# :::::::::::::::::::::::::::::::::::::::::::::::::: lof ::::::::::::::::::::::::::::::::::::::::::::::::::

# %%
t = time.time()-start

if t>=(60*60):
    t = f"{round(t/(60*60),2)}hrs."
elif t>120 and t<(60*60):
    t = f"{round(t/(60),2)}min."
elif t<120:
    t = f"{round(t,0)}sec."

print(f"Run time = {t}")
# Out:
# Run time = 18.43hrs.
